# %% [markdown]
# <a href="https://colab.research.google.com/github/smishra9/64060-SUMIT.DUTT.MISHRA/blob/main/Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib
# %matplotlib inline

# %%
titanic = pd.read_csv('/content/train.csv')

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ####We could clearly understand we can remove passengerid, ticket from dataset

# %%
titanic = titanic.drop(['PassengerId','Ticket'], axis =1)

# %%
titanic.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C

# %%
titanic = titanic.drop(['Name'], axis =1)

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.scatter(titanic.SibSp,titanic.Survived)

# %%
titanic = titanic[titanic.SibSp<= 5]

# %%
plt.scatter(titanic.SibSp,titanic.Survived)

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         170
# SibSp         0
# Parch         0
# Fare          0
# Cabin       680
# Embarked      2
# dtype: int64

# %%
titanic= titanic.drop(['Cabin'], axis = 1)

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data = titanic

# %%
plt.hist(titanic.Age)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
data =data.fillna(data.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  882 non-null    int64
#  1   Pclass    882 non-null    int64
#  2   Sex       882 non-null    object
#  3   Age       882 non-null    float64
#  4   SibSp     882 non-null    int64
#  5   Parch     882 non-null    int64
#  6   Fare      882 non-null    float64
#  7   Embarked  882 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.0+ KB

# %%
data.Embarked.value_counts()
# Out:
# S    637
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
adults = {'male':1,'female':0}
ad = data.Sex.map(adults)
data['Sex'] = ad

# %%
data
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    1  22.000000      1      0   7.2500        S
# 1           1       1    0  38.000000      1      0  71.2833        C
# 2           1       3    0  26.000000      0      0   7.9250        S
# 3           1       1    0  35.000000      1      0  53.1000        S
# 4           0       3    1  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    1  27.000000      0      0  13.0000        S
# 887         1       1    0  19.000000      0      0  30.0000        S
# 888         0       3    0  29.699118      1      2  23.4500        S
# 889         1       1    1  26.000000      0      0  30.0000        C
# 890         0       3    1  32.000000      0      0   7.7500        Q
#
# [882 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()

# %%
data['Embarked'] = model.fit_transform(data['Embarked'])

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %% [markdown]
# ####Dividing the data into training and test

# %%
from sklearn.model_selection import train_test_split
data_train,data_test= train_test_split(data,test_size = 0.25,random_state=42)

# %%
data_train.head()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 601         0       3    1  29.699118      0      0   7.8958         2
# 521         0       3    1  22.000000      0      0   7.8958         2
# 452         0       1    1  30.000000      0      0  27.7500         0
# 819         0       3    1  10.000000      3      2  27.9000         2
# 772         0       2    0  57.000000      0      0  10.5000         2

# %%
data_test.head()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 44          1       3    0  19.000000      0      0   7.8792         1
# 339         0       1    1  45.000000      0      0  35.5000         2
# 87          0       3    1  29.699118      0      0   8.0500         2
# 458         1       2    0  50.000000      0      0  10.5000         2
# 469         1       3    0   0.750000      2      1  19.2583         0

# %% [markdown]
# #####Creating dependent and independent variable

# %%
training_pred = data_train.drop(['Survived'], axis =1 )
training_target = data_train['Survived']
testing_pred = data_test.drop(['Survived'], axis =1 )
testing_target = data_test['Survived']

# %%
training_pred
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 601       3    1  29.699118      0      0   7.8958         2
# 521       3    1  22.000000      0      0   7.8958         2
# 452       1    1  30.000000      0      0  27.7500         0
# 819       3    1  10.000000      3      2  27.9000         2
# 772       2    0  57.000000      0      0  10.5000         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 107       3    1  29.699118      0      0   7.7750         2
# 274       3    0  29.699118      0      0   7.7500         1
# 869       3    1   4.000000      1      1  11.1333         2
# 440       2    0  45.000000      1      1  26.2500         2
# 103       3    1  33.000000      0      0   8.6542         2
#
# [661 rows x 7 columns]

# %% [markdown]
# ####Importing decision tree

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier(criterion='gini',max_depth= 9)

# %%
model.fit(training_pred,training_target)
# Out:
# DecisionTreeClassifier(max_depth=9)

# %%
model.score(training_pred,training_target)
# Out:
# 0.9152798789712556

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.3480191256830601, 0.95, 'X[1] <= 0.5\ngini = 0.47\nsamples = 661\nvalue = [412, 249]'),
#  Text(0.16530054644808742, 0.85, 'X[0] <= 2.5\ngini = 0.38\nsamples = 216\nvalue = [55, 161]'),
#  Text(0.07650273224043716, 0.75, 'X[2] <= 2.5\ngini = 0.112\nsamples = 117\nvalue = [7, 110]'),
#  Text(0.06557377049180328, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08743169398907104, 0.65, 'X[5] <= 29.356\ngini = 0.098\nsamples = 116\nvalue = [6, 110]'),
#  Text(0.06557377049180328, 0.55, 'X[5] <= 28.231\ngini = 0.174\nsamples = 52\nvalue = [5, 47]'),
#  Text(0.0546448087431694, 0.45, 'X[2] <= 56.0\ngini = 0.145\nsamples = 51\nvalue = [4, 47]'),
#  Text(0.03278688524590164, 0.35, 'X[3] <= 0.5\ngini = 0.115\nsamples = 49\nvalue = [3, 46]'),
#  Text(0.02185792349726776, 0.25, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.04371584699453552, 0.25, 'X[5] <= 22.0\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.02185792349726776, 0.15, 'X[5] <= 17.429\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01092896174863388, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03278688524590164, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06557377049180328, 0.15, 'X[2] <= 43.0\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.0546448087431694, 0.05, 'gini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.07650273224043716, 0.05, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07650273224043716, 0.35, 'X[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06557377049180328, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08743169398907104, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07650273224043716, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1092896174863388, 0.55, 'X[4] <= 1.5\ngini = 0.031\nsamples = 64\nvalue = [1, 63]'),
#  Text(0.09836065573770492, 0.45, 'gini = 0.0\nsamples = 51\nvalue = [0, 51]'),
#  Text(0.12021857923497267, 0.45, 'X[2] <= 24.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.1092896174863388, 0.35, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.13114754098360656, 0.35, 'X[2] <= 28.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.12021857923497267, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14207650273224043, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.2540983606557377, 0.75, 'X[6] <= 1.5\ngini = 0.5\nsamples = 99\nvalue = [48, 51]'),
#  Text(0.19672131147540983, 0.65, 'X[2] <= 37.35\ngini = 0.326\nsamples = 39\nvalue = [8, 31]'),
#  Text(0.18579234972677597, 0.55, 'X[5] <= 6.987\ngini = 0.301\nsamples = 38\nvalue = [7, 31]'),
#  Text(0.17486338797814208, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19672131147540983, 0.45, 'X[5] <= 14.852\ngini = 0.272\nsamples = 37\nvalue = [6, 31]'),
#  Text(0.18579234972677597, 0.35, 'X[5] <= 13.935\ngini = 0.355\nsamples = 26\nvalue = [6, 20]'),
#  Text(0.16393442622950818, 0.25, 'X[4] <= 1.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.15300546448087432, 0.15, 'X[2] <= 21.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.14207650273224043, 0.05, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.16393442622950818, 0.05, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.17486338797814208, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20765027322404372, 0.25, 'X[2] <= 16.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.19672131147540983, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2185792349726776, 0.15, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20765027322404372, 0.35, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.20765027322404372, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3114754098360656, 0.65, 'X[5] <= 7.7\ngini = 0.444\nsamples = 60\nvalue = [40, 20]'),
#  Text(0.3005464480874317, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3224043715846995, 0.55, 'X[5] <= 17.35\ngini = 0.408\nsamples = 56\nvalue = [40, 16]'),
#  Text(0.28415300546448086, 0.45, 'X[5] <= 9.84\ngini = 0.48\nsamples = 35\nvalue = [21, 14]'),
#  Text(0.26229508196721313, 0.35, 'X[4] <= 0.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.25136612021857924, 0.25, 'X[2] <= 54.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.24043715846994534, 0.15, 'X[5] <= 8.767\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.22950819672131148, 0.05, 'gini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.25136612021857924, 0.05, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.26229508196721313, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.273224043715847, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30601092896174864, 0.35, 'X[2] <= 38.35\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.29508196721311475, 0.25, 'X[4] <= 1.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.28415300546448086, 0.15, 'X[2] <= 28.85\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.273224043715847, 0.05, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.29508196721311475, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30601092896174864, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.31693989071038253, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36065573770491804, 0.45, 'X[2] <= 5.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.34972677595628415, 0.35, 'X[2] <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.33879781420765026, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36065573770491804, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37158469945355194, 0.35, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5307377049180327, 0.85, 'X[2] <= 6.5\ngini = 0.317\nsamples = 445\nvalue = [357, 88]'),
#  Text(0.37158469945355194, 0.75, 'X[3] <= 2.5\ngini = 0.432\nsamples = 19\nvalue = [6, 13]'),
#  Text(0.36065573770491804, 0.65, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.3825136612021858, 0.65, 'X[4] <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.37158469945355194, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.39344262295081966, 0.55, 'X[2] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3825136612021858, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40437158469945356, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6898907103825137, 0.75, 'X[5] <= 26.269\ngini = 0.29\nsamples = 426\nvalue = [351, 75]'),
#  Text(0.5204918032786885, 0.65, 'X[2] <= 13.5\ngini = 0.212\nsamples = 324\nvalue = [285, 39]'),
#  Text(0.4371584699453552, 0.55, 'X[5] <= 17.344\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4262295081967213, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44808743169398907, 0.45, 'X[4] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4371584699453552, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45901639344262296, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6038251366120219, 0.55, 'X[6] <= 0.5\ngini = 0.2\nsamples = 320\nvalue = [284, 36]'),
#  Text(0.5081967213114754, 0.45, 'X[2] <= 29.35\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.4808743169398907, 0.35, 'X[5] <= 15.394\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.46994535519125685, 0.25, 'X[2] <= 28.75\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.45901639344262296, 0.15, 'X[2] <= 22.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.44808743169398907, 0.05, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.46994535519125685, 0.05, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4808743169398907, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4918032786885246, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5355191256830601, 0.35, 'X[4] <= 0.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.5245901639344263, 0.25, 'X[5] <= 13.369\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.5027322404371585, 0.15, 'X[5] <= 7.227\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.4918032786885246, 0.05, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5136612021857924, 0.05, 'gini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.546448087431694, 0.15, 'X[5] <= 14.456\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5355191256830601, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5573770491803278, 0.05, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.546448087431694, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6994535519125683, 0.45, 'X[5] <= 13.25\ngini = 0.177\nsamples = 286\nvalue = [258, 28]'),
#  Text(0.6557377049180327, 0.35, 'X[5] <= 7.91\ngini = 0.203\nsamples = 235\nvalue = [208, 27]'),
#  Text(0.6120218579234973, 0.25, 'X[2] <= 29.35\ngini = 0.132\nsamples = 127\nvalue = [118, 9]'),
#  Text(0.5901639344262295, 0.15, 'X[2] <= 23.5\ngini = 0.226\nsamples = 54\nvalue = [47, 7]'),
#  Text(0.5792349726775956, 0.05, 'gini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(0.6010928961748634, 0.05, 'gini = 0.365\nsamples = 25\nvalue = [19, 6]'),
#  Text(0.6338797814207651, 0.15, 'X[5] <= 7.763\ngini = 0.053\nsamples = 73\nvalue = [71, 2]'),
#  Text(0.6229508196721312, 0.05, 'gini = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.644808743169399, 0.05, 'gini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.6994535519125683, 0.25, 'X[5] <= 7.988\ngini = 0.278\nsamples = 108\nvalue = [90, 18]'),
#  Text(0.6775956284153005, 0.15, 'X[3] <= 1.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.6666666666666666, 0.05, 'gini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.6885245901639344, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7213114754098361, 0.15, 'X[2] <= 19.5\ngini = 0.234\nsamples = 96\nvalue = [83, 13]'),
#  Text(0.7103825136612022, 0.05, 'gini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.73224043715847, 0.05, 'gini = 0.198\nsamples = 81\nvalue = [72, 9]'),
#  Text(0.7431693989071039, 0.35, 'X[3] <= 1.5\ngini = 0.038\nsamples = 51\nvalue = [50, 1]'),
#  Text(0.73224043715847, 0.25, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(0.7540983606557377, 0.25, 'X[6] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7431693989071039, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7650273224043715, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8592896174863388, 0.65, 'X[2] <= 25.0\ngini = 0.457\nsamples = 102\nvalue = [66, 36]'),
#  Text(0.8087431693989071, 0.55, 'X[3] <= 1.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.7978142076502732, 0.45, 'X[2] <= 17.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.7868852459016393, 0.35, 'X[4] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7759562841530054, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7978142076502732, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8087431693989071, 0.35, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.819672131147541, 0.45, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.9098360655737705, 0.55, 'X[2] <= 53.0\ngini = 0.489\nsamples = 80\nvalue = [46, 34]'),
#  Text(0.8415300546448088, 0.45, 'X[5] <= 27.135\ngini = 0.5\nsamples = 64\nvalue = [32, 32]'),
#  Text(0.8306010928961749, 0.35, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8524590163934426, 0.35, 'X[2] <= 27.5\ngini = 0.49\nsamples = 56\nvalue = [32, 24]'),
#  Text(0.825136612021858, 0.25, 'X[5] <= 144.115\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.8142076502732241, 0.15, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8360655737704918, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8797814207650273, 0.25, 'X[5] <= 115.442\ngini = 0.477\nsamples = 51\nvalue = [31, 20]'),
#  Text(0.8579234972677595, 0.15, 'X[4] <= 0.5\ngini = 0.454\nsamples = 46\nvalue = [30, 16]'),
#  Text(0.8469945355191257, 0.05, 'gini = 0.484\nsamples = 39\nvalue = [23, 16]'),
#  Text(0.8688524590163934, 0.05, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9016393442622951, 0.15, 'X[2] <= 32.35\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.8907103825136612, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.912568306010929, 0.05, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9781420765027322, 0.45, 'X[6] <= 1.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.9672131147540983, 0.35, 'X[3] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.9562841530054644, 0.25, 'X[2] <= 57.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9453551912568307, 0.15, 'X[5] <= 33.098\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9344262295081968, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9562841530054644, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9672131147540983, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9781420765027322, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9890710382513661, 0.35, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]')]

# %%
label_test = model.predict(testing_pred)

# %%
from ssl import ALERT_DESCRIPTION_BAD_RECORD_MAC
from sklearn.metrics import accuracy_score
acc = accuracy_score(label_test,testing_target)

# %%
acc
# Out:
# 0.8144796380090498

# %% [markdown]
# ####We are achieving the accuracy of 82% which is pretty good according to the data
